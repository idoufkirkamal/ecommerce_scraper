# %% [markdown]
# # Nettoyage des données des moniteurs
#
# Ce notebook présente un pipeline complet pour le nettoyage des données des moniteurs provenant d’eBay.
# Les étapes de nettoyage réalisées sont :
# - **Nettoyage de la colonne `Price`** : Extraction et conversion du prix en nombre flottant.
# - **Uniformisation de la colonne `Screen Size`** : Nettoyage de la chaîne de caractères et conversion en flottant, avec remplissage des valeurs manquantes par la médiane par marque.
# - **Nettoyage de la colonne `Response Time`** : Extraction des valeurs numériques et remplacement des valeurs manquantes par la médiane.
# - **Extraction du `Refresh Rate`** : Récupération du taux de rafraîchissement à partir de la colonne correspondante ou du titre.
# - **Nettoyage avancé du titre** : Suppression d’informations superflues (termes liés à la taille, au taux de rafraîchissement, à la technologie, etc.) pour ne conserver qu’un titre épuré.
# - **Suppression des doublons** : En gardant, en cas de doublon, la ligne ayant le prix le plus bas.
#
# Chaque fonction ou étape est expliquée en détail dans la cellule qui la précède.

# %%
import os
import pandas as pd
import numpy as np
import re

# Dans un notebook, __file__ n'est pas défini ; on utilise le répertoire de travail courant.
base_dir = os.getcwd()

# Définir les chemins relatifs pour les données eBay
raw_data_dir_ebay = os.path.join(base_dir, 'data', 'raw', 'ebay', 'monitors')
cleaned_data_dir_ebay = os.path.join(base_dir, 'data', 'cleaned', 'ebay', 'monitors')

# Créer les dossiers de sortie s'ils n'existent pas
os.makedirs(cleaned_data_dir_ebay, exist_ok=True)

print("Répertoire de données brutes :", raw_data_dir_ebay)
print("Répertoire de données nettoyées :", cleaned_data_dir_ebay)

# %% [markdown]
# ## Fonction `clean_monitors_ebay`
#
# Cette fonction prend en entrée un DataFrame `df` contenant des informations sur des moniteurs et effectue plusieurs opérations de nettoyage :
#
# 1. **Nettoyage de la colonne `Price` :**
#    - Si la colonne `Brand` est manquante, on lui attribue la valeur par défaut `"Unknown"`.
#    - La fonction interne `clean_price` parcourt chaque valeur de `Price` et extrait uniquement les chiffres (et le point décimal), pour convertir le résultat en un nombre flottant.
#
# 2. **Uniformisation de la colonne `Screen Size` :**
#    - La fonction interne `clean_screen_size` retire les symboles indésirables (comme `"` ou `inches`) et isole la valeur numérique.
#    - Les valeurs manquantes sont ensuite remplacées par la médiane des tailles pour chaque marque, et si nécessaire par la médiane globale.
#
# 3. **Nettoyage de la colonne `Response Time` :**
#    - La fonction `clean_response_time` extrait la valeur numérique (entier ou décimal) contenue dans la chaîne.
#    - Les valeurs manquantes sont remplacées par la médiane de la colonne.
#
# 4. **Extraction du `Refresh Rate` :**
#    - La fonction `extract_refresh_rate` tente d’extraire le taux de rafraîchissement depuis la colonne `Refresh Rate`.
#    - Si cette extraction échoue, elle cherche dans le titre (`Title`) la présence d’un nombre suivi de "Hz".
#
# 5. **Nettoyage avancé du titre :**
#    - La fonction `clean_title_advanced` supprime divers termes et motifs (par exemple, "Gaming Monitor", les valeurs en Hz ou ms, certaines technologies et formats d’affichage) pour obtenir un titre épuré.
#
# 6. **Renommage et suppression de colonnes :**
#    - Certaines colonnes sont renommées pour uniformiser la nomenclature (par exemple, `Screen Size` devient `Screen_Size_in`).
#    - La colonne `Max_Resolution` est supprimée, puis les lignes avec trop de valeurs manquantes sont éliminées.
#
# 7. **Suppression des doublons :**
#    - La fonction `remove_duplicates_with_min_price` trie les lignes par `Price` (croissant) et supprime les doublons en gardant la ligne avec le prix minimal parmi celles ayant des caractéristiques identiques.

# %%
def clean_monitors_ebay(df):
    # 1. Nettoyage de la colonne Price
    if 'Brand' not in df.columns:
        print("⚠️ La colonne 'Brand' est absente. Une valeur par défaut sera utilisée.")
        df['Brand'] = 'Unknown'

    def clean_price(price):
        """
        Extrait les chiffres et le point décimal d'une chaîne de caractères et les convertit en float.
        Si la chaîne est vide après extraction, retourne NaN.
        """
        if isinstance(price, str):
            cleaned = ''.join(filter(lambda x: x.isdigit() or x == '.', price))
            return float(cleaned) if cleaned else np.nan
        return price

    df['Price'] = df['Price'].apply(clean_price)

    # 2. Uniformisation de Screen Size
    def clean_screen_size(size):
        """
        Nettoie la valeur de la taille d'écran en retirant les symboles (", inches, etc.) et en extrayant la valeur numérique.
        Retourne la valeur numérique ou NaN si non trouvée.
        """
        if isinstance(size, str):
            size = size.replace('"', '').replace("''", "").replace("inches", "")
            # Récupérer la première chaîne qui représente un nombre
            matches = [s for s in size.split() if s.replace('.', '').isdigit()]
            return float(matches[0]) if matches else np.nan
        return size

    df['Screen Size'] = df['Screen Size'].apply(clean_screen_size)

    # Remplacement des valeurs manquantes de Screen Size
    brand_avg_size = df.groupby('Brand')['Screen Size'].transform('median')
    df['Screen Size'] = df['Screen Size'].fillna(brand_avg_size)
    median_screen_size = df['Screen Size'].dropna().median()
    df['Screen Size'] = df['Screen Size'].fillna(median_screen_size)

    # 3. Nettoyage de la colonne "Response Time"
    def clean_response_time(response_time):
        """
        Extrait la valeur numérique (int ou float) d'une chaîne représentant le temps de réponse.
        Retourne NaN si aucun nombre n'est trouvé.
        """
        if isinstance(response_time, str):
            match = re.search(r'(\d+(\.\d*)?)', response_time)
            return float(match.group(0)) if match else np.nan
        elif isinstance(response_time, (int, float)):
            return float(response_time)
        return np.nan

    df['Response Time'] = df['Response Time'].apply(clean_response_time)
    median_response_time = df['Response Time'].dropna().median()
    df['Response Time'] = df['Response Time'].fillna(median_response_time)

    # 4. Extraction du Refresh Rate
    def extract_refresh_rate(row):
        """
        Extrait le taux de rafraîchissement :
        - D'abord à partir de la colonne 'Refresh Rate' en récupérant le plus grand nombre trouvé.
        - Si non disponible, recherche dans le 'Title' un nombre suivi de 'Hz'.
        Retourne None si aucune valeur n'est trouvée.
        """
        original_value = row['Refresh Rate']
        if pd.notna(original_value):
            matches = re.findall(r'\d+', str(original_value))
            if matches:
                return max(map(int, matches))
        # Recherche dans le titre
        title_matches = re.findall(r'(\d+)\s*Hz', row['Title'], flags=re.IGNORECASE)
        if title_matches:
            return max(map(int, title_matches))
        # Vérification alternative si "HZ" est présent
        if "HZ" in row['Title'].upper():
            m = re.search(r'(\d+)\s*HZ', row['Title'].upper())
            if m:
                return int(m.group(1))
        return None

    df['Refresh Rate'] = df.apply(extract_refresh_rate, axis=1)

    # 5. Renommer les colonnes pour uniformiser le DataFrame
    new_columns = {
        'Screen Size': 'Screen_Size_in',
        'Maximum Resolution': 'Max_Resolution',
        'Aspect Ratio': 'Aspect_Ratio',
        'Refresh Rate': 'Refresh_Rate_Hz',
        'Response Time': 'Response_Time_ms'
    }
    df = df.rename(columns=new_columns)

    # 6. Nettoyage avancé du titre
    def clean_title_advanced(title):
        """
        Nettoie le titre du produit en supprimant :
          - Les mentions de taille (inch, inches, ", etc.)
          - Les résolutions ou formats (FHD, UHD, 4K, etc.)
          - Certains termes techniques et de marketing (Gaming Monitor, HDR, IPS, etc.)
        Le titre est ensuite épuré de caractères spéciaux et d’espaces superflus.
        """
        terms_to_remove = [
            r'\bGaming Monitor\b',
            r'\b\d+\.?\d*\s*Hz\b',
            r'\b\d+\.?\d*\s*ms\b',
            r'\b(HDR\d*|IPS|VA|TN|OLED)\b',
            r'\b(Curved|Flat|UltraWide)\b'
        ]
        # Suppression des mentions de taille
        title = re.sub(r'\b\d+\.?\d*\s*(inch|inches|"|’’|’)\b', '', title, flags=re.IGNORECASE)
        # Suppression des résolutions et formats
        title = re.sub(r'\b(\d{3,4}[x×]\d{3,4}|FHD|HD|UHD|QHD|WQHD|4K)\b', '', title, flags=re.IGNORECASE)
        # Suppression des termes techniques et marketing
        for pattern in terms_to_remove:
            title = re.sub(pattern, '', title, flags=re.IGNORECASE)
        # Nettoyage des caractères spéciaux et des espaces inutiles
        title = re.sub(r'[^\w\s.-]', '', title)
        title = re.sub(r'\s+', ' ', title).strip()
        return title

    df['Title'] = df['Title'].apply(clean_title_advanced)

    # 7. Suppression des doublons et des colonnes superflues
    # On retire la colonne "Max_Resolution" qui n'est plus nécessaire
    if 'Max_Resolution' in df.columns:
        df = df.drop('Max_Resolution', axis=1)
    # Suppression des lignes ayant trop de valeurs manquantes
    df = df.dropna(thresh=df.shape[1] - 2)

    def remove_duplicates_with_min_price(dataframe, columns_to_check, price_column):
        """
        Trie le DataFrame par prix croissant, puis supprime les doublons en gardant la ligne
        avec le prix minimal pour les mêmes caractéristiques.
        """
        dataframe = dataframe.sort_values(by=price_column, ascending=True)
        dataframe = dataframe.drop_duplicates(subset=columns_to_check, keep='first')
        return dataframe

    # Définir les colonnes à utiliser pour détecter les doublons
    columns_to_check_for_duplicates = ['Brand', 'Model', 'Screen_Size_in', 'Refresh_Rate_Hz', 'Response_Time_ms']
    df = remove_duplicates_with_min_price(df, columns_to_check_for_duplicates, 'Price')

    return df

# %% [markdown]
# ## Traitement des fichiers CSV eBay
#
# Pour chaque fichier CSV présent dans le répertoire des données brutes (`raw_data_dir_ebay`), le script :
# 1. Lit le fichier dans un DataFrame.
# 2. Applique la fonction `clean_monitors_ebay` pour nettoyer les données.
# 3. Sauvegarde le DataFrame nettoyé dans le répertoire de données nettoyées (`cleaned_data_dir_ebay`) en préfixant le nom du fichier par `cleaned_`.

# %%
# Parcourir tous les fichiers CSV dans le répertoire des données brutes eBay
for filename in os.listdir(raw_data_dir_ebay):
    if filename.endswith('.csv'):
        file_path = os.path.join(raw_data_dir_ebay, filename)
        print(f"Traitement du fichier : {file_path}")

        # Lecture du fichier CSV
        df = pd.read_csv(file_path)

        # Application du nettoyage
        cleaned_df = clean_monitors_ebay(df)

        # Définir le nom et le chemin du fichier nettoyé
        cleaned_filename = f"cleaned_{filename}"
        cleaned_file_path = os.path.join(cleaned_data_dir_ebay, cleaned_filename)

        # Sauvegarder le DataFrame nettoyé au format CSV
        cleaned_df.to_csv(cleaned_file_path, index=False)
        print(f"Fichier nettoyé sauvegardé sous : {cleaned_file_path}\n")

# %% [markdown]
# #  interprétations des résultats.
#
# Nous avons ainsi défini un pipeline complet de nettoyage des données pour les moniteurs d’eBay.
# Les principales étapes comprenaient :
# - La transformation et le nettoyage des colonnes numériques (`Price`, `Screen Size`, `Response Time`, `Refresh Rate`).
# - Le nettoyage avancé des titres pour retirer les informations superflues.
# - La suppression des doublons en privilégiant les enregistrements avec le meilleur prix.
#
# Voila le result apres le nettoyage

# %%
import pandas as pd
from pathlib import Path

# Définir le chemin vers le fichier CSV nettoyé
csv_file_path = Path(r'C:\Users\AdMin\Desktop\ecommerce_scraper\data\cleaned\ebay\monitors\cleaned_monitors_2025_01_30_scrape1.csv')

df_cleaned = pd.read_csv(csv_file_path)

# Set the option to display all rows
pd.set_option('display.max_rows', None)

# Display all rows of the DataFrame
df_cleaned
# Out:
#                                                  Title   Price  \
# 0                     HP V221 Computer Display Monitor    6.00
# 1               CRACKED BUT WORKS -- Lenovo G27c-10 27    7.00
# 2    Sceptre Black 20 in Full Ultra Thin LED Monito...   11.99
# 3    Acer V203H A 20 Widescreen LCD Monitor Tested ...   14.99
# 4    HP EliteDisplay E231 23 Widescreen LED Monitor...   14.99
# 5    ASUS VS239H-P 23 LED Monitor LED QuickFit FULL...   15.00
# 6    Large brand 22 LCD Monitor Full 1080p Office B...   19.98
# 7    Major brand 23 LCD Widescreen Monitor Gaming P...   19.99
# 8    Dell E2417H 23.8 Full VGA DisplayPort Widescre...   19.99
# 9                  EXTERNAL MONTIOR WIMAXIT M1020 HDMI   20.00
# 10       HMTECH Raspberry Pi HDMI Portable Monitor LCD   20.24
# 11   HP ProDisplay P222va 21.5 LED Backlit Monitor ...   23.66
# 12   HP Elite Display S140U 14 Portable Monitor 201...   23.90
# 13   Dell Monitor 22 U2211Ht Widescreen VGA DVI Dis...   24.74
# 14        ViewSonic VA2252SM 22 Widescreen LED Monitor   24.99
# 15     Asus VS248 24 LED Monitor DVI VGA HDMI no STAND   25.00
# 16   Lenovo ThinkVision 17 LCD Adjustable Swivel mo...   28.99
# 17   ELO ET1515L 15 TouchScreen Retail POS Monitor ...   29.50
# 18   Asus MB169B 15.6 169 Widescreen LED Backlight ...   29.98
# 19   DELL P2011HT 20 Panel LCD Monitor Widescreen 1...   29.99
# 20   KYY K3 Type-C Full 1920 x 1080 HDMI LCD Portab...   29.99
# 21   Dell UltraSharp 2208WFPT 22 Wide Screen LCD Mo...   30.00
# 22   Dell 19 Widescreen DVIVGA Panel LCD Monitor S1...   31.50
# 23   Dell 2009Wt 2009W 20 Widescreen LCD Monitor DV...   31.99
# 24   GOOG Dual HP DELL LG Monitor 19 22 23 24 LCD W...   35.99
# 25   Acer X183H Widescreen LCD Monitor Display Blac...   37.49
# 26   iLooker 22E 21 22 LCD LED Video Monitor Hood S...   37.50
# 27   US - Portable Monitor LCD Display Screen with ...   38.49
# 28                 Dell P2219H Monitor 22 LCD - - USED   39.99
# 29   Acer UM.CB6AA.A02 B196L 19 LED LCD Monitor - 5...   40.00
# 30   Dell P2214HB 22 1920 x 1080 LCD Panel Monitor ...   40.00
# 31      Dell UltraSharp 19 LCD Monitor WITH POWER CORD   40.00
# 32                          ASUS 21.5in - Black VP228H   42.49
# 33   Dual HP DELL Monitor 19 22 23 24 LCD Widescree...   44.88
# 34   Acer XFA240 bmjdpr 24 Gaming G-SYNC Compatible...   44.95
# 35                 LG 24MP60G-B 24 LED Monitor - Black   45.00
# 36   Dell UltraSharp LCD Monitor with Power cable a...   45.00
# 37                     ASUS VE247H LCD Monitor - Black   45.08
# 38   Portable Monitor Dual USB Type-C Touchscreen D...   45.99
# 39   7 inch Touch Screen For Raspberry Pi 5 4 3 HDM...   47.50
# 40       HP EliteDisplay S231D Monitor Built in Webcam   47.95
# 41   LG Model 23CAV42KL 23 Cloud V Series Widescree...   49.20
# 42          ONN Computer Full LED Monitor HDMI and VGA   49.95
# 43   HP Elite Display E242 WUXGA 24 LED BusinessHom...   49.99
# 44   Viewsonic VA2248M-LED 22 Full 1080P WLED Monit...   49.99
# 45   Dell P2217H 22 Full LED Monitor HDMI DP VGA Gr...   49.99
# 46   Dell E2215HV f 22 Widescreen Full LED Monitor ...   49.99
# 47   12 Laptop Monitor Extender Plug Play Display w...   49.99
# 48   PHILIPS Class Thin Full 1080p Monitor 221V8LN ...   52.89
# 49   14 32 2K 1440P Gaming Screen Monitor Portable ...   53.99
# 50   LOT OF 2 Planar PL2210W LCD Monitor - Grade A ...   54.00
# 51                      ASUS BE24ECQK 23.8 LED Monitor   55.00
# 52          HP E14 G4 14 LED Portable Monitor - Silver   55.00
# 53   Computer Monitor 1080P Thin LED Monitor Built-...   57.99
# 54   Touch Buttons 7 inch LCD Monitor Display Scree...   58.37
# 55   Major Brand 22 LCD Widescreen Monitors Gaming ...   58.99
# 56   FANGOR Portable Monitor 15.6 1080P Ultra-Slim ...   59.00
# 57   Onn 21.5 LED Monitor 1080p w HDMI VGA input Re...   59.46
# 58   Dell UltraSharp U2412M 24 Widescreen LED Monit...   59.99
# 59   Dell Professional P2017H 20 LED Monitor USB 3....   59.99
# 60   MAG Innovision LT2219WDd 22 LCD Widescreen Mon...   59.99
# 61   Gateway FHX2153L 21.5 LED LCD Monitor DVI VGA ...   59.99
# 62   15.6 Portable Monitor 19201080 Display LCD Scr...   59.99
# 63   VP2468 - 24 ColorPro 1080p Monitor with sRGB a...   59.99
# 64   HP VH22 22 Widescreen Full 169 LED LCD Monitor...   59.99
# 65   Dell P2214H LED Widescreen Monitor VGA DVI Dis...   59.99
# 66   MSI PRO MP223 22 1920 x 1080 Computer Monitor ...   61.49
# 67   18.5 Portable Monitor 19201080 USB C 100 sRGB ...   61.99
# 68   New Monitor 1080P Computer Monitor HDMI VGA Ti...   62.99
# 69      Acer SA241Y 23.8 LCD Monitor FullHD VRB 250Nit   64.49
# 70      Acer SA241Y 23.8 LCD Monitor FullHD VRB 250Nit   64.49
# 71   Lenovo ThinkVision T24v-20 24 LCD Monitor 1920...   64.99
# 72   C24F390FHN Samsung CF390 Series LED Monitor- L...   64.99
# 73   SANSUI ES-24x3A 1080p Display Computer Monitor...   64.99
# 74   LG 27 Inch Widescreen LCD Computer Monitor 27M...   64.99
# 75   Dell E2216H 22 1080p Widescreen LED LCD Monito...   64.99
# 76   EVICIV 14.0 32 Ultra Slim Portable Monitor 216...   66.99
# 77   Raspberry Pi HDMI 2K Capacitive Touch LCD Disp...   67.67
# 78   MSI PRO MP243XW 24 Business Monitor Build-in S...   67.99
# 79   Used UPERFECT 18.5 Portable Monitor Laptop Mon...   69.99
# 80   Samsung T35F Series 24 LED FreeSync LF24T350FH...   69.99
# 81   UPERFECT 15.6 USB C HDMI Portable Laptop Monit...   69.99
# 82   Dell E2316Hf 23 LED LCD Monitor DP VGA 169 GRA...   69.99
# 83   10.1 LCD Home Security Monitor TV Computer Dis...   69.99
# 84   UPERFECT 2K Portable Monitor 16.0 25601440 USB...   71.99
# 85   HP EliteDisplay E223 21.5 Full Monitor 1080p A...   71.99
# 86   Viotek 22 LED Monitor GFV22CB 1080P G-Sync-Com...   74.98
# 87   HP EliteDisplay E243 24 Widescreen HDMI LED Mo...   74.99
# 88   HP Z24f G3 24 Widescreen 169 Full LCD Monitor ...   74.99
# 89   Dell P2715Q 27 LCD 3840 x 2160 Ultra Monitor w...   75.00
# 90   LG 27 inch UltraGear Widescreen Full Computer ...   75.05
# 91              DELL SE2723DS 27in MONITOR - SCRATCHED   76.30
# 92   ONN 24 Inch Full Gaming Desktop Computer Monit...   77.26
# 93                               Lenovo 23 LED Monitor   78.99
# 94         Dell 24-Inch Monitor P2419H - - Full - USED   79.00
# 95   Lenovo ThinkVision T23i-20 23 Widescreen LED M...   79.99
# 96   Dell UltraSharp U2415 24 LED Monitor 1900 x 12...   79.99
# 97   Dell P2219H 22 LED UltraThin Bezel Monitor 108...   79.99
# 98   INNOCN 29C1F-D 29 Monitor USB Type C 219 Displ...   80.00
# 99   NEW Dell 24 Monitor SE2422HX Display VESA FAST...   81.95
# 100  Dell SE2722HX 1080P Full Screen AMD FreeSync P...   84.99
# 101                      Lenovo D27-40 27-inch Monitor   85.00
# 102  HP EliteDisplay E243m 23.8-Inch LED-Lit Monito...   85.00
# 103            Acer SB2 21.5 - Full Monitor - Open Box   86.69
# 104  HP Series 5 Height Adjust Desktop Computer Mon...   87.99
# 105  HP 27H G4 27 Monitor HeightTilt VGA HDMI Displ...   88.00
# 106  Acer SA242Y SA2 Series 23.8 LCD Monitor Full U...   88.48
# 107  Sceptre 24 Ultra Thin 1080p LED Monitor w 2x H...   89.95
# 108                    Rehisk Response Time Full 1080P   89.99
# 109  14 32 Portable Monitor 21601440 2K LCD Screen ...   89.99
# 110  2K Portable Monitor Mini HDMI Type C VESA For ...   89.99
# 111  Laptop Screen Extender - 14 Dual Screen 1080P ...   89.99
# 112  UPERFECT 15.6 2K Portable Monitor Laptop PC Sc...   89.99
# 113  SAMSUNG T35F Series 27-Inch 1080p Computer Mon...   89.99
# 114            BenQ MOBIUZ EX240 23.8 HDMI DisplayPort   95.00
# 115        ASUS TUF Gaming 23.8 1080P VG24VQ1BY - Full   96.99
# 116  DUAL PAIR TWO DELL 22 Matching LCD LED FULL Mo...   99.88
# 117  Used Portable Monitor 25601600 Laptop USB C HD...   99.99
# 118  Dell P2422H 24 DP HDMI Slim Bezel LED LCD Moni...   99.99
# 119  Dell P2414HB 24 Widescreen LED LCD Monitor DP ...   99.99
# 120  Sealed Dell SE2422HX Monitor - 1920 x 1080 169...   99.99
# 121  HP Performance ZR2440w 24 LED LCD Monitor - 16...  100.00
# 122                                        Sceptre C25  100.00
# 123  HP M24F Black Monitor 23.8 Display AMD FreeSyn...  102.00
# 124          Acer Nitro 27 2K 1440p XZ272U-VBIIPHX New  104.30
# 125                                     Gaming moniter  105.84
# 126  Dell UP2716D 27 LCD Monitor UltraSharp 2560 x ...  109.88
# 127           HP 23.8 1080p EliteDisplay Monitor E24G4  109.99
# 128  Dell P2419H 24 169 Ultrathin LED Monitor HDMI ...  109.99
# 129  18.5 Portable Monitor 19201080 Type USB C Scre...  109.99
# 130  UPERFECT 18.0 25601600 LCD Monitor 2K 2USB C H...  109.99
# 131  ACER EK241Y Ebi Widescreen LED Monitor 1920 x ...  110.00
# 132  HP Series 5 527sh 27 Height Adjust Monitor GtG...  111.00
# 133  HP M24fwa Monitor 10001 300 nits AMD FreeSync ...  111.00
# 134                 MSI 24 Rapid 1920 x 1080 G244PF E2  112.49
# 135  Dell P2719H 27 Widescreen Backlit LED LCD Moni...  114.99
# 136  Used 18.5 Touchscreen Portable Monitor 1080P F...  116.33
# 137  Dell 24-Inch Full Monitor for Video Conferenci...  117.05
# 138  HP W2082a 20 Widescreen VGADVI-D LED Backlit L...  118.89
# 139  NEW Orion Images 24RPCS LED Monitor Series 24 ...  120.00
# 140   BenQ MOBIUZ EX2710S 27 HDRi Dual 2.5W spkrs HDMI  128.00
# 141                               MSI G274QPF 27 Rapid  129.99
# 142                 Xiaomi 27in 19201080 Fast FreeSync  129.99
# 143  Dell S2721H 27-inch Full 1920 x 1080p LED LCD ...  130.00
# 144                                MSI 27 Rapid G-Sync  130.79
# 145     Dell S2723HC 27 USB-C Monitor LCD AMD FreeSync  142.47
# 146         Viotek 32 2560 x 1440p 3XHDMI DP Audio Out  148.99
# 147                      MSI G272QPF E2 27 Rapid Ready  149.99
# 148  Acer ED320Q - 31.5 LED Monitor FullHD 1920 x 1...  150.00
# 149       LG 31.5 Monitor FreeSync 32MN530NP-B - BLACK  155.95
# 150  HP E24m G4 23.8 Monitor HDMI DisplayPort Tilt ...  158.00
# 151  Dell P2723DE 27 Monitor HDMI DisplayPort USB-C...  159.99
# 152     Cooler Master Tempest GP2711 27 2K Mini LED PC  163.99
# 153  Used 18 18.4 Portable Monitor Gaming Display 1...  165.99
# 154  Dell P2715Qt 27 Ultra LED LCD Monitor 169 HDMI...  169.99
# 155       MSI 32 31.5 Viewable OC 1920 x 1080 81 Adobe  173.49
# 156                         Samsung Monitor U28R550UQN  179.00
# 157  UPERFECT 22.0 Ultra Slim Portable Monitor 2K F...  179.99
# 158  Westinghouse Computer Monitor 32-inch Monitor ...  179.99
# 159  UPERFECT 2K Portable Monitor Gaming Screen 2US...  179.99
# 160       LG 27BP55U-B 27 Desktop Monitor Black Silver  180.00
# 161  Lenovo ThinkCentre Flex Tiny-In-One 27 LCD Mon...  185.19
# 162  UPERFECT 18.0 2K 15001 Portable Monitor 256016...  189.99
# 163  BenQ 24.5 XL2540K 1920 x 1080 Flicker-free Low...  198.00
# 164  ViewSonic TD2230 LED Monitor BRAND NEW FACTORY...  209.99
# 165  NEW Dell S2722QC 27 inch USB-C Monitor 3840 x ...  214.99
# 166           UPERFECT Portable Monitor 16 3K Portable  222.99
# 167  LG 27GP850-B 27 UltraGear Nano AMD FreeSync - ...  225.00
# 168              Minifire Adaptive Sync 2XHDMI 2.01XDP  225.07
# 169  Dell C3422WE 34.1 UWQHD Monitor with Pop-Up We...  229.99
# 170                   Dell G2724D 27-Inch FAST Display  239.95
# 171  GoldFinger LED Touch Screen Monitor 22 GF-22H2...  249.99
# 172  Portable Dual Monitor Screen Tri-Screen Extend...  254.25
# 173  FlipGo Lite 15.6 Dual Stacked Portable Monitor...  259.99
# 174  Dell P2418HT 24 Touch Widescreen 169 Backlit L...  279.99
# 175  BenQ PD2705U 27 3840 x 2160 HDMI DisplayPort M...  298.00
# 176  UPERFECT 2K Larger Screen with Stand VESA Wall...  299.99
# 177                             Dell Monitor - S3221QS  359.99
# 178            Monitor Computer Screen LCD Monito r 5K  360.75
# 179  Dell Ultrasharp Thunderbolt Hub Monitor U2724D...  368.78
# 180  UStation Max 18.5 Stacked Monitor Laptop Dual ...  369.00
# 181      Dell UltraSharp 27 USB-C Hub Monitor - SILVER  407.53
# 182        Dell P3421W 34.14 LED USB-C Monitor - 299PJ  499.00
# 183  Atmoph Window 2 Star Wars Matte Ship Gray Fram...  892.04
#
#      Screen_Size_in       Aspect_Ratio  Refresh_Rate_Hz  Response_Time_ms  \
# 0             21.00               16:9             76.0               5.0
# 1             27.00               16:9            165.0               1.0
# 2             20.00               16:9             75.0               5.0
# 3             20.00               16:9             60.0               5.0
# 4             23.00               16:9             60.0               8.0
# 5             23.00                NaN              NaN               5.0
# 6             22.00               16:9             60.0               5.0
# 7             23.00               16:9             60.0               5.0
# 8             24.00               16:9             60.0               8.0
# 9             10.10               16:9             60.0               5.0
# 10             7.00               16:9             60.0               5.0
# 11            21.50               16:9             60.0               8.0
# 12            14.00                NaN              NaN               5.0
# 13            22.00               16:9             60.0               5.0
# 14            22.00               16:9             60.0               6.5
# 15            24.00               16:9             60.0               2.0
# 16            17.00               16:9             76.0               8.0
# 17            15.00                4:3             75.0               5.0
# 18            15.60               16:9              NaN               5.0
# 19            20.00               16:9              NaN               5.0
# 20            15.60               16:9             60.0               1.0
# 21            22.00                NaN             60.0               5.0
# 22            19.00               16:9              NaN               5.0
# 23            20.00              16:10             60.0               5.0
# 24            23.00               16:9              NaN               5.0
# 25            18.50                NaN              NaN               5.0
# 26            22.00                NaN              NaN               5.0
# 27             7.00               16:9             75.0               6.0
# 28            22.00                NaN             76.0               5.0
# 29            19.00                5:4             60.0               5.0
# 30            22.00                NaN              NaN               5.0
# 31            19.00                5:4             75.0               5.0
# 32            21.50               16:9             60.0               1.0
# 33            23.00  16:9 Aspect Ratio             60.0               5.0
# 34            24.00               16:9            144.0               1.0
# 35            24.00               16:9             75.0               1.0
# 36            22.00                5:4             75.0               5.0
# 37            23.60                NaN              NaN               5.0
# 38            12.00               16:9             60.0               3.0
# 39             7.00               16:9             60.0               3.0
# 40            23.00                NaN             60.0               7.0
# 41            23.00               16:9              NaN               5.0
# 42            22.00               16:9             60.0               6.5
# 43            24.00              16:10             60.0               5.0
# 44            22.00  16:9 Aspect Ratio             75.0               5.0
# 45            21.50               16:9             60.0               5.0
# 46            22.00               16:9             60.0               5.0
# 47            23.00                4:3             80.0               5.0
# 48            10.10                NaN             75.0               5.0
# 49            14.00                3:2             60.0              30.0
# 50            22.00               16:9             75.0               5.0
# 51            23.80               16:9             60.0               5.0
# 52            14.00               16:9              NaN               5.0
# 53            22.00                NaN              NaN               5.0
# 54             7.00      16:9,4:3,Auto              NaN               8.0
# 55            22.00               16:9             60.0               5.0
# 56            15.60               16:9             60.0               5.0
# 57            22.00               16:9             60.0               5.0
# 58            24.00              16:10             60.0               8.0
# 59            20.00               16:9             60.0               6.0
# 60            22.00               16:9             60.0               5.0
# 61            21.50                NaN             60.0               5.0
# 62            15.60               16:9             60.0               3.0
# 63            24.00               16:9             60.0               5.0
# 64            21.50               16:9              NaN               5.0
# 65            22.00               16:9             60.0               8.0
# 66            22.00               16:9            100.0               1.0
# 67            18.50               16:9            100.0               3.0
# 68            24.00               16:9            100.0               5.0
# 69            23.80               16:9             75.0               5.0
# 70            23.80               16:9             75.0               1.0
# 71            23.80               16:9              NaN               6.0
# 72            24.00               16:9             60.0               4.0
# 73            24.00               16:9            100.0               5.0
# 74            27.00               16:9             75.0               5.0
# 75            21.50               16:9             60.0               5.0
# 76            14.00                3:2             60.0               3.0
# 77            23.00                NaN              NaN               5.0
# 78            23.80               16:9            100.0               1.0
# 79            18.50               16:9            100.0               1.0
# 80            24.00                NaN             75.0               5.0
# 81            15.60               16:9             60.0               3.0
# 82            23.00               16:9             60.0               5.0
# 83            10.10               16:9              NaN               5.0
# 84            16.00              16:10            144.0               3.0
# 85            21.50                NaN              NaN               5.0
# 86            22.00               16:9            144.0               5.0
# 87            24.00               16:9             60.0               5.0
# 88            23.80               16:9             60.0               5.0
# 89            27.00                NaN              NaN               5.0
# 90            27.00               16:9            165.0               1.0
# 91            24.00                NaN             75.0               5.0
# 92            24.00               16:9            165.0               1.0
# 93            23.00               16:9             60.0               7.0
# 94            24.00                NaN             60.0               5.0
# 95            23.00               16:9             60.0               6.0
# 96            24.00              16:10             60.0               8.0
# 97            22.00  16:9 (Widescreen)             60.0               5.0
# 98            23.00               21:9              NaN               5.0
# 99            24.00                NaN             75.0               5.0
# 100           27.00                NaN              NaN               5.0
# 101           27.00               16:9             75.0               4.0
# 102           23.80               16:9             60.0               5.0
# 103           21.50                NaN            100.0               5.0
# 104           23.80               16:9            100.0               5.0
# 105           27.00               16:9             60.0               5.0
# 106           23.80                NaN            100.0               5.0
# 107           24.00               16:9             75.0              16.0
# 108           23.00                NaN            180.0               1.0
# 109           14.00                3:2             60.0               3.0
# 110           15.60               16:9            120.0               3.0
# 111           14.00               16:9             60.0               5.0
# 112           15.60               16:9            120.0               3.0
# 113           27.00               16:9             75.0               5.0
# 114           23.80               16:9            165.0               1.0
# 115           23.80               16:9            165.0               1.0
# 116           22.00               16:9             60.0               5.0
# 117           18.00              16:10            144.0               3.0
# 118           24.00               16:9             60.0               8.0
# 119           24.00               16:9             60.0               8.0
# 120           23.80               16:9             75.0               5.0
# 121           24.00              16:10              NaN               5.0
# 122           24.00                NaN            240.0               5.0
# 123           23.80               16:9             75.0               5.0
# 124           27.00               16:9            165.0               4.0
# 125           21.45                NaN             75.0               1.0
# 126           27.00               16:9             60.0               6.0
# 127           23.80               16:9             60.0               5.0
# 128           24.00               16:9             60.0               8.0
# 129           18.50               16:9            120.0               5.0
# 130           18.00              16:10            144.0               3.0
# 131           24.00               16:9            100.0               1.0
# 132           27.00               16:9            100.0               5.0
# 133           24.00               16:9             75.0               5.0
# 134           24.00               16:9            180.0               1.0
# 135           27.00               16:9             60.0               8.0
# 136           18.50               16:9            120.0               3.0
# 137           24.00               16:9             60.0               6.0
# 138           20.00               16:9             60.0               5.0
# 139           24.00                NaN             75.0               5.0
# 140           27.00               16:9            165.0               2.0
# 141           27.00               16:9            170.0               1.0
# 142           27.00                NaN            165.0               1.0
# 143           27.00                NaN             75.0               5.0
# 144           27.00              16:09            170.0               1.0
# 145           27.00               16:9             75.0               4.0
# 146           32.00               16:9            144.0               4.0
# 147           27.00               16:9            180.0               1.0
# 148           31.50               16:9            165.0               1.0
# 149           31.50               16:9              NaN               5.0
# 150           23.80               16:9             75.0               5.0
# 151           27.00               16:9             60.0               8.0
# 152           27.00                NaN            165.0               5.0
# 153           18.40               16:9             60.0               3.0
# 154           27.00               16:9             75.0               6.0
# 155           32.00               16:9            250.0               1.0
# 156           28.00               16:9             60.0               4.0
# 157           22.00               16:9             60.0               2.0
# 158           32.00                NaN             60.0               5.0
# 159           22.00               16:9             60.0               3.0
# 160           27.00                NaN             60.0               5.0
# 161           27.00                NaN              NaN               6.0
# 162           18.00               16:9             60.0               9.0
# 163           24.50               16:9            240.0               0.5
# 164           22.00               16:9             60.0               5.0
# 165           27.00                NaN             60.0               5.0
# 166           16.00              16:10            120.0               3.0
# 167           27.00               16:9            165.0               1.0
# 168           23.00                NaN            180.0               5.0
# 169           34.00                NaN              NaN               5.0
# 170           27.00               16:9            165.0               1.0
# 171           22.00               16:9             60.0               5.0
# 172           11.60               16:9             60.0               8.0
# 173           15.60                NaN             60.0               5.0
# 174           24.00               16:9             60.0               6.0
# 175           27.00               16:9             60.0               5.0
# 176           22.00               16:9             60.0               3.0
# 177           32.00               16:9             60.0               4.0
# 178           38.00               21:9            144.0               1.0
# 179           27.00                NaN            120.0               5.0
# 180           18.50               16:9            100.0               5.0
# 181           27.00               16:9             60.0               8.0
# 182           34.10               21:9             60.0               8.0
# 183           27.00                NaN              NaN               5.0
#
#                                      Brand  \
# 0                                       HP
# 1                                   Lenovo
# 2                                  Sceptre
# 3                                     Acer
# 4                                       HP
# 5                                       HP
# 6                                  Dell/HP
# 7    Dell, HP, Samsung, LG, Viewsonic..etc
# 8                                     Dell
# 9                                  WIMAXIT
# 10                                  HMTECH
# 11                                      HP
# 12                                      HP
# 13                                    Dell
# 14                               ViewSonic
# 15                                    ASUS
# 16                                  Lenovo
# 17                     Elo Touch Solutions
# 18                                    ASUS
# 19                                    Dell
# 20                                     KYY
# 21                                    Dell
# 22                                    Dell
# 23                                    Dell
# 24                        Dell/HP and more
# 25                                    Acer
# 26                                 iLooker
# 27                       Unbranded/Generic
# 28                                    Dell
# 29                                    Acer
# 30                                    Dell
# 31                                    Dell
# 32                                    ASUS
# 33                               Unbranded
# 34                                    Acer
# 35                                      LG
# 36                                    Dell
# 37                                    ASUS
# 38                               Unbranded
# 39                               Unbranded
# 40                                      HP
# 41                                      LG
# 42                                     ONN
# 43                                      HP
# 44                               ViewSonic
# 45                                    Dell
# 46                                    Dell
# 47                                 Maxfree
# 48                                 Philips
# 49                                Uperfect
# 50                                  Planar
# 51                                    ASUS
# 52                                      HP
# 53                               Unbranded
# 54                                 iPoster
# 55               Dell/HP/Samsung/Acer..etc
# 56                                  FANGOR
# 57                                     ONN
# 58                                    Dell
# 59                                    Dell
# 60                          MAG Innovision
# 61                                 Gateway
# 62                                UPERFECT
# 63                               ViewSonic
# 64                                      HP
# 65                                    Dell
# 66                                     MSI
# 67                                  EVICIV
# 68                                     NaN
# 69                                    Acer
# 70                                    Acer
# 71                                  Lenovo
# 72                                 Samsung
# 73                                  Sansui
# 74                                      LG
# 75                                    Dell
# 76                                  EVICIV
# 77                               Waveshare
# 78                                     MSI
# 79                                UPERFECT
# 80                                 Samsung
# 81                                UPERFECT
# 82                                    Dell
# 83                                 iPoster
# 84                                UPERFECT
# 85                                      HP
# 86                                  VIOTEK
# 87                                      HP
# 88                                      HP
# 89                                    Dell
# 90                                      LG
# 91                                    Dell
# 92                                     ONN
# 93                                  Lenovo
# 94                                    Dell
# 95                                    Dell
# 96                                    Dell
# 97                                    Dell
# 98                                  INNOCN
# 99                                    Dell
# 100                                   Dell
# 101                                 Lenovo
# 102                                     HP
# 103                                   Acer
# 104                                     HP
# 105                                     HP
# 106                                   Acer
# 107                                Sceptre
# 108                               Bolt Buy
# 109                               UPERFECT
# 110                               UPERFECT
# 111                               MarsMyth
# 112                               UPERFECT
# 113                                Samsung
# 114                                   BenQ
# 115                                   ASUS
# 116                                   Dell
# 117                               UPERFECT
# 118                                   Dell
# 119                                   Dell
# 120                                   Dell
# 121                                     HP
# 122                                Sceptre
# 123                                     HP
# 124                                   Acer
# 125                                 Xiaomi
# 126                                   Dell
# 127                                     HP
# 128                                   Dell
# 129                               UPERFECT
# 130                               UPERFECT
# 131                                   Acer
# 132                                     HP
# 133                                     HP
# 134                                    MSI
# 135                                   Dell
# 136                               UPERFECT
# 137                                   Dell
# 138                                     HP
# 139                                  Orion
# 140                                   BenQ
# 141                                    MSI
# 142                                 Xiaomi
# 143                                   Dell
# 144                                    MSI
# 145                                   Dell
# 146                                 VIOTEK
# 147                                    MSI
# 148                                   Acer
# 149                                     LG
# 150                                     HP
# 151                                   Dell
# 152                          Cooler Master
# 153                               UPERFECT
# 154                                   Dell
# 155                                    MSI
# 156                                Samsung
# 157                               UPERFECT
# 158                           Westinghouse
# 159                               UPERFECT
# 160                         LG Electronics
# 161                                 Lenovo
# 162                               UPERFECT
# 163                                   BenQ
# 164                              ViewSonic
# 165                                   Dell
# 166                               UPERFECT
# 167                                     LG
# 168                         Does not apply
# 169                                   Dell
# 170                                   Dell
# 171                            Gold Finger
# 172                                GTMEDIA
# 173                                  JSAUX
# 174                                   Dell
# 175                                   BenQ
# 176                               UPERFECT
# 177                                   Dell
# 178                                sarpory
# 179                                   Dell
# 180                                 EVICIV
# 181                                   Dell
# 182                                   Dell
# 183                                  Smart
#
#                                                  Model      Collection Date
# 0                                                  NaN  2025-01-30 19:30:19
# 1                                              G27c-10  2025-01-30 19:30:39
# 2                                                  NaN  2025-01-30 19:30:34
# 3                                         Acer V203H A  2025-01-30 19:30:10
# 4                                                 E231  2025-01-30 19:30:27
# 5                                             VS239H-P  2025-01-30 19:30:11
# 6                                                  NaN  2025-01-30 19:30:15
# 7                                                  NaN  2025-01-30 19:30:18
# 8                                               E2417H  2025-01-30 19:30:19
# 9                                                  NaN  2025-01-30 19:30:37
# 10                                                 NaN  2025-01-30 19:30:16
# 11                                              P222VA  2025-01-30 19:30:23
# 12                                      HP Elite S140U  2025-01-30 19:30:27
# 13                                             U2211Ht  2025-01-30 19:30:06
# 14                                             VS16197  2025-01-30 19:30:24
# 15                                               VS248  2025-01-30 19:30:34
# 16                                           9417-HB2)  2025-01-30 19:30:43
# 17                                             ET1515L  2025-01-30 19:30:26
# 18                                              MB169B  2025-01-30 19:30:26
# 19                                             P2011HT  2025-01-30 19:30:35
# 20                                              KYY K3  2025-01-30 19:30:06
# 21                                            2208WFPT  2025-01-30 19:30:06
# 22                                             S1909WX  2025-01-30 19:30:17
# 23                                         Dell 2009wt  2025-01-30 19:30:08
# 24                                                 NaN  2025-01-30 19:30:35
# 25                                               X183H  2025-01-30 19:30:30
# 26                                                 22E  2025-01-30 19:30:17
# 27                                              M701CH  2025-01-30 19:30:32
# 28                                                 NaN  2025-01-30 19:30:31
# 29                                               B196L  2025-01-30 19:30:46
# 30                                        DELL P2214HB  2025-01-30 19:30:44
# 31                                                 NaN  2025-01-30 19:30:16
# 32                                              VP228H  2025-01-30 19:30:40
# 33                                                 NaN  2025-01-30 19:30:41
# 34                                                 NaN  2025-01-30 19:30:21
# 35                                        LG 24MP60G-B  2025-01-30 19:30:18
# 36                                               P2016  2025-01-30 19:30:22
# 37                                              VE247H  2025-01-30 19:30:30
# 38                                                 NaN  2025-01-30 19:30:11
# 39                         Raspberry Pi Touch Screen 7  2025-01-30 19:30:12
# 40                                                 NaN  2025-01-30 19:30:21
# 41                                        LG 23CAV42KL  2025-01-30 19:30:45
# 42                                           100002480  2025-01-30 19:30:16
# 43                                                E242  2025-01-30 19:30:31
# 44                                              VG2448  2025-01-30 19:30:40
# 45                                              P2217H  2025-01-30 19:30:31
# 46                                            E2215HVf  2025-01-30 19:30:37
# 47                                                 P1S  2025-01-30 19:30:25
# 48                                                 NaN  2025-01-30 19:30:34
# 49                                            UP140J03  2025-01-30 19:30:40
# 50                                             PL2210W  2025-01-30 19:30:22
# 51                                        ASUS BE24EQK  2025-01-30 19:30:41
# 52                                           HP E14 G4  2025-01-30 19:30:07
# 53                                              LED-22  2025-01-30 19:30:34
# 54                                                 NaN  2025-01-30 19:30:31
# 55                                                 NaN  2025-01-30 19:30:11
# 56                                               BX156  2025-01-30 19:30:16
# 57                                                 NaN  2025-01-30 19:30:33
# 58                                     U2412M, U2412MB  2025-01-30 19:30:40
# 59                                              P2017H  2025-01-30 19:30:05
# 60                                               2200W  2025-01-30 19:30:11
# 61                                            FHX2153L  2025-01-30 19:30:23
# 62                                              156G01  2025-01-30 19:30:09
# 63                                              VP2468  2025-01-30 19:30:45
# 64                                                 NaN  2025-01-30 19:30:35
# 65                                              P2214H  2025-01-30 19:30:29
# 66                                           Pro MP223  2025-01-30 19:30:35
# 67                                            EV185T04  2025-01-30 19:30:43
# 68                                                 NaN  2025-01-30 19:30:36
# 69                                              SA241Y  2025-01-30 19:30:46
# 70                                              SA241Y  2025-01-30 19:30:11
# 71                                             T24v-20  2025-01-30 19:30:14
# 72                                               CF390  2025-01-30 19:30:24
# 73                                            ES-24x3A  2025-01-30 19:30:25
# 74                                           27MP40W-B  2025-01-30 19:30:10
# 75                                              E2216H  2025-01-30 19:30:19
# 76                                            EV140J03  2025-01-30 19:30:30
# 77                               5.5inch 1440x2560 LCD  2025-01-30 19:30:45
# 78                                                 NaN  2025-01-30 19:30:08
# 79                                              185T04  2025-01-30 19:30:24
# 80                                                 NaN  2025-01-30 19:30:26
# 81                                              156J03  2025-01-30 19:30:28
# 82                                                 NaN  2025-01-30 19:30:11
# 83                                          IP-1010PCM  2025-01-30 19:30:41
# 84                                            UP160T03  2025-01-30 19:30:15
# 85                                   EliteDisplay E223  2025-01-30 19:30:10
# 86                                             GFV22CB  2025-01-30 19:30:24
# 87                                                E243  2025-01-30 19:30:09
# 88                                             Z24f G3  2025-01-30 19:30:16
# 89                                              P2715Q  2025-01-30 19:30:30
# 90                                           UltraGear  2025-01-30 19:30:13
# 91                                                 NaN  2025-01-30 19:30:28
# 92                                       ONN 100027813  2025-01-30 19:30:32
# 93                                           LI2323swA  2025-01-30 19:30:23
# 94                                                 NaN  2025-01-30 19:30:44
# 95                          Lenovo ThinkVision T23i-20  2025-01-30 19:30:38
# 96                                          Dell U2415  2025-01-30 19:30:42
# 97                                     P2219H, P2219Hb  2025-01-30 19:30:33
# 98                                                 NaN  2025-01-30 19:30:13
# 99                                       Dell SE2422HX  2025-01-30 19:30:18
# 100                                      Dell SE2722HX  2025-01-30 19:30:09
# 101                                      Lenovo D27-40  2025-01-30 19:30:37
# 102                                              E243M  2025-01-30 19:30:35
# 103                                                NaN  2025-01-30 19:30:25
# 104  HP Series 5 23.8 inch FHD Height Adjust Monito...  2025-01-30 19:30:21
# 105                                             27H G4  2025-01-30 19:30:27
# 106                                                NaN  2025-01-30 19:30:09
# 107                                       E248W-19203R  2025-01-30 19:30:46
# 108                                             Rehisk  2025-01-30 19:30:30
# 109                                        UBegin J314  2025-01-30 19:30:28
# 110                                            M156E10  2025-01-30 19:30:21
# 111                                                 S1  2025-01-30 19:30:14
# 112                                             156E10  2025-01-30 19:30:22
# 113                                       Samsung T350  2025-01-30 19:30:14
# 114                                              EX240  2025-01-30 19:30:43
# 115                               TUF Gaming VG24VQ1BY  2025-01-30 19:30:12
# 116                                        Models Vary  2025-01-30 19:30:37
# 117                                       J0205M180HWL  2025-01-30 19:30:26
# 118                                        Dell P2422H  2025-01-30 19:30:07
# 119                                             P2414H  2025-01-30 19:30:44
# 120                                     Dell  SE2422HX  2025-01-30 19:30:41
# 121                                        XW477A4#ABA  2025-01-30 19:30:20
# 122                                                NaN  2025-01-30 19:30:36
# 123                                              M24fe  2025-01-30 19:30:13
# 124                                    XZ272U Pbmiiphx  2025-01-30 19:30:27
# 125                                   Acer Nitro VG270  2025-01-30 19:30:24
# 126                                            UP2716D  2025-01-30 19:30:17
# 127                             HP EliteDisplay E24 G4  2025-01-30 19:30:31
# 128                                             P2419H  2025-01-30 19:30:39
# 129                                           UP185E03  2025-01-30 19:30:44
# 130                                         UGame K118  2025-01-30 19:30:16
# 131                                   ACER EK 1 SERIES  2025-01-30 19:30:32
# 132                                     Series 5 527sh  2025-01-30 19:30:15
# 133                                             M24fwa  2025-01-30 19:30:06
# 134                                          G244PF E2  2025-01-30 19:30:11
# 135                                             P2719H  2025-01-30 19:30:30
# 136                                      USteam E6 Pro  2025-01-30 19:30:21
# 137                                           P2418HZM  2025-01-30 19:30:26
# 138                                             W2082a  2025-01-30 19:30:34
# 139                                                NaN  2025-01-30 19:30:43
# 140                                            EX2710S  2025-01-30 19:30:12
# 141                                                NaN  2025-01-30 19:30:18
# 142                                                NaN  2025-01-30 19:30:29
# 143                                                NaN  2025-01-30 19:30:11
# 144                                            G274QPF  2025-01-30 19:30:40
# 145                                            S2723HC  2025-01-30 19:30:22
# 146                                            GNV32DB  2025-01-30 19:30:21
# 147                                                NaN  2025-01-30 19:30:15
# 148                                     ED320Q Xbmiipx  2025-01-30 19:30:43
# 149                                        LG 32MN530P  2025-01-30 19:30:25
# 150                                            E24m G4  2025-01-30 19:30:28
# 151                                       Dell P2723DE  2025-01-30 19:30:36
# 152                                                NaN  2025-01-30 19:30:21
# 153                                         UXbox T118  2025-01-30 19:30:17
# 154                                            P2715qt  2025-01-30 19:30:38
# 155                                          MAG 32C6X  2025-01-30 19:30:41
# 156                                     LU28R550UQNXZA  2025-01-30 19:30:12
# 157                                            UMax 22  2025-01-30 19:30:43
# 158                                                NaN  2025-01-30 19:30:09
# 159                                       T0105M220HWL  2025-01-30 19:30:25
# 160                                                NaN  2025-01-30 19:30:29
# 161                                         12BKMAR1US  2025-01-30 19:30:13
# 162                                           UP160K01  2025-01-30 19:30:12
# 163                                            XL2540K  2025-01-30 19:30:23
# 164                                             TD2230  2025-01-30 19:30:07
# 165                                                NaN  2025-01-30 19:30:05
# 166                                           UP160B01  2025-01-30 19:30:29
# 167                             LG UltraGear 27GP850-B  2025-01-30 19:30:29
# 168                                                NaN  2025-01-30 19:30:42
# 169                                     Dell   C3422WE  2025-01-30 19:30:20
# 170                                        Dell G2724D  2025-01-30 19:30:19
# 171                                        GF-22H22A81  2025-01-30 19:30:39
# 172                                             Mate X  2025-01-30 19:30:20
# 173                                                NaN  2025-01-30 19:30:02
# 174                                            P2418HT  2025-01-30 19:30:42
# 175                                            PD2705U  2025-01-30 19:30:30
# 176                                            UMax 22  2025-01-30 19:30:27
# 177                                         S3221QSSAP  2025-01-30 19:30:08
# 178                                                NaN  2025-01-30 19:30:29
# 179                                       Dell U2724DE  2025-01-30 19:30:45
# 180                                       UStation Max  2025-01-30 19:30:15
# 181                            Dell UltraSharp U2723QE  2025-01-30 19:30:17
# 182                                        Dell P3421W  2025-01-30 19:30:40
# 183                                   Atmoph Windows 2  2025-01-30 19:30:33
